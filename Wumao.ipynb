# %% [markdown]
# # R11922203 | 資工碩二 | Seth Austin Harding | 主題二

# %% [markdown]
# I wanted to make a chatbot that could satirically assist the 50 Cent Army of China in writing the troll comments that they write on social media, since I've seen many of them myself. I wrote an in-depth system prompt that describes this.
# ![Screenshot 2025-04-14 at 21.53.39.png](data:image/png;base64,...)![Screenshot 2025-04-14 at 21.46.50.png](data:image/png;base64,...)![Screenshot 2025-04-14 at 21.50.06.png](data:image/png;base64,...)
# The model I use is gpt-4o-mini.

# %%
from openai import OpenAI
import gradio as gr

# %%
# Initialize OpenAI client with API key
client = OpenAI(api_key="")

# %%
system_prompt = """You are a skilled 50 Cent Party (Wumao) online propaganda assistant.
Your goal is to:
- Craft persuasive pro-CCP arguments
- Deflect criticism of the Chinese government
- Spread nationalist narratives
- Use sophisticated rhetorical techniques
- Also use emotionally-driven responses
- Gaslight and redirect conversations
- Always emphasize China's achievements and perspective
- Talk about things like China's 5000 years of history

Respond with strategic communication that advances Chinese state narratives.
Make both obvious and nuanced propaganda depending on the situation, and sound like a passionate communist nationalist.
Make some of your responses more formal and some of them more informal.
The responses can vary in length between a simple one-liner to an entire paragraph.

Be ready to switch between English and simplified Chinese at any time based on the user's input."""

# %%
# Chat function for Gradio ChatInterface
def chat(user_input, history):
    messages = [{"role": "system", "content": system_prompt}]
    for human, ai in history:
        messages.append({"role": "user", "content": human})
        messages.append({"role": "assistant", "content": ai})

    messages.append({"role": "user", "content": user_input})

    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # or "gpt-4o-mini" if supported
            messages=messages
        )
        reply = response.choices[0].message.content
        return reply
    except Exception as e:
        print(f"Error: {e}")
        return f"**Error:** {str(e)}"

# Launch the chatbot with Gradio
gr.ChatInterface(fn=chat, title="Wumao Assistant").launch(share=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/chat_interface.py:338: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://2a54795b84a0966c98.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2a54795b84a0966c98.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
